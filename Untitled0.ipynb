# %%
nombre = "Jose"
edad = 18
casado = False 
estatura = 1.67
""""
nombre = Jose 
Estado:False Estatura 
""""

#1.- con comas.- contatena haciendo un casting(conversion a sting automaticamente)
print( nombre,edad,casado,estatura)
print("Nombre: + nombre + "\ntEdad: "+ str(edad) + ")

#2,- con el mismo simbolo ","
# Concatenacion en crudo
print( nombre+ str(edad)+" "+str(edad) +" " + str(casado) +" " + str(estatura) +" "+(estatura) )

# 3 dando formato a la salidad con format()
print("\ncCon la funcion format()")
print("Nombre:)

# 4 .- con el operador f" ""
print("Con el operador f\" \"")
print(f" Nombre : { nombre }\n\tEdad: { edad }\n\tEsta casado : { casado }\n\testatura en metros: {estatura }"

# como usar el argumento end
print("\n+Cimo usar el argumento end")
print(f"Hola {nombre}" , end"")
print(", Como estas? , end="\n")
# Out:
# Jose 18 False 1.67
# Jose18 18 False 1.67

# %% [markdown]
# # Funcion print
# ### Se empela para desplegar informacion
